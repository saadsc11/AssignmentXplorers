# %% [markdown]
# # SIMPLE LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\cindr\Downloads\delivery_time.csv")

# %%
df
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
df.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
df.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
a = df['Sorting Time']
b = df['Delivery Time']

# %%
a
# Out:
# 0     10
# 1      4
# 2      6
# 3      9
# 4     10
# 5      6
# 6      7
# 7      3
# 8     10
# 9      9
# 10     8
# 11     4
# 12     7
# 13     3
# 14     3
# 15     4
# 16     6
# 17     7
# 18     2
# 19     7
# 20     5
# Name: Sorting Time, dtype: int64

# %%
b
# Out:
# 0     21.00
# 1     13.50
# 2     19.75
# 3     24.00
# 4     29.00
# 5     15.35
# 6     19.00
# 7      9.50
# 8     17.90
# 9     18.75
# 10    19.83
# 11    10.75
# 12    16.68
# 13    11.50
# 14    12.03
# 15    14.88
# 16    13.75
# 17    18.11
# 18     8.00
# 19    17.83
# 20    21.50
# Name: Delivery Time, dtype: float64

# %%
sns.pairplot(df, kind= 'reg')
plt.show()

# %%
df.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
corr = np.corrcoef(a,b)
print(corr)
# Out:
# [[1.         0.82599726]
#  [0.82599726 1.        ]]

# %%
model = sm.OLS(b,a).fit()
predictions = model.predict(a)

# %%
predictions
# Out:
# 0     25.652463
# 1     10.260985
# 2     15.391478
# 3     23.087216
# 4     25.652463
# 5     15.391478
# 6     17.956724
# 7      7.695739
# 8     25.652463
# 9     23.087216
# 10    20.521970
# 11    10.260985
# 12    17.956724
# 13     7.695739
# 14     7.695739
# 15    10.260985
# 16    15.391478
# 17    17.956724
# 18     5.130493
# 19    17.956724
# 20    12.826231
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.953
# Method:                 Least Squares   F-statistic:                              424.5
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    6.12e-15
# Time:                        16:39:54   Log-Likelihood:                         -57.349
# No. Observations:                  21   AIC:                                      116.7
# Df Residuals:                      20   BIC:                                      117.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#log transformation on a
a_log = np.log(df['Sorting Time'])
print(a_log)
# Out:
# 0     2.302585
# 1     1.386294
# 2     1.791759
# 3     2.197225
# 4     2.302585
# 5     1.791759
# 6     1.945910
# 7     1.098612
# 8     2.302585
# 9     2.197225
# 10    2.079442
# 11    1.386294
# 12    1.945910
# 13    1.098612
# 14    1.098612
# 15    1.386294
# 16    1.791759
# 17    1.945910
# 18    0.693147
# 19    1.945910
# 20    1.609438
# Name: Sorting Time, dtype: float64

# %%
#new model with log transformed x data    
model1 = sm.OLS(b,a_log).fit()

# %%
pred1 = model1.predict(a_log)
print(pred1)
# Out:
# 0     22.267289
# 1     13.406244
# 2     17.327319
# 3     21.248394
# 4     22.267289
# 5     17.327319
# 6     18.818042
# 7     10.624197
# 8     22.267289
# 9     21.248394
# 10    20.109366
# 11    13.406244
# 12    18.818042
# 13    10.624197
# 14    10.624197
# 15    13.406244
# 16    17.327319
# 17    18.818042
# 18     6.703122
# 19    18.818042
# 20    15.564167
# dtype: float64

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.974
# Method:                 Least Squares   F-statistic:                              791.0
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    1.48e-17
# Time:                        16:39:54   Log-Likelihood:                         -51.035
# No. Observations:                  21   AIC:                                      104.1
# Df Residuals:                      20   BIC:                                      105.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#log transform b data 
b_log = np.log(df['Delivery Time'])
b_log
# Out:
# 0     3.044522
# 1     2.602690
# 2     2.983153
# 3     3.178054
# 4     3.367296
# 5     2.731115
# 6     2.944439
# 7     2.251292
# 8     2.884801
# 9     2.931194
# 10    2.987196
# 11    2.374906
# 12    2.814210
# 13    2.442347
# 14    2.487404
# 15    2.700018
# 16    2.621039
# 17    2.896464
# 18    2.079442
# 19    2.880882
# 20    3.068053
# Name: Delivery Time, dtype: float64

# %%
model2 = sm.OLS(b_log, a).fit()
pred2 = model2.predict(a)
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.917
# Model:                            OLS   Adj. R-squared (uncentered):              0.912
# Method:                 Least Squares   F-statistic:                              219.7
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    3.00e-12
# Time:                        16:39:54   Log-Likelihood:                         -25.284
# No. Observations:                  21   AIC:                                      52.57
# Df Residuals:                      20   BIC:                                      53.61
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#log transformed x and y data 
model3 = sm.OLS(b_log, a_log).fit()
pred3 = model3.predict(a_log)
print(pred3)
# Out:
# 0     3.545002
# 1     2.134304
# 2     2.758547
# 3     3.382791
# 4     3.545002
# 5     2.758547
# 6     2.995874
# 7     1.691396
# 8     3.545002
# 9     3.382791
# 10    3.201455
# 11    2.134304
# 12    2.995874
# 13    1.691396
# 14    1.691396
# 15    2.134304
# 16    2.758547
# 17    2.995874
# 18    1.067152
# 19    2.995874
# 20    2.477850
# dtype: float64

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.972
# Model:                            OLS   Adj. R-squared (uncentered):              0.970
# Method:                 Least Squares   F-statistic:                              688.7
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    5.72e-17
# Time:                        16:39:54   Log-Likelihood:                         -13.899
# No. Observations:                  21   AIC:                                      29.80
# Df Residuals:                      20   BIC:                                      30.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# square root transformation on a and b
a_sqrt = np.sqrt(df['Sorting Time'])
model4 = sm.OLS(b, a_sqrt).fit()
pred4 = model4.predict(a_sqrt)
print(pred4)
model4.summary()
# Out:
# 0     21.967162
# 1     13.893253
# 2     17.015691
# 3     20.839880
# 4     21.967162
# 5     17.015691
# 6     18.379046
# 7     12.031910
# 8     21.967162
# 9     20.839880
# 10    19.648027
# 11    13.893253
# 12    18.379046
# 13    12.031910
# 14    12.031910
# 15    13.893253
# 16    17.015691
# 17    18.379046
# 18     9.824014
# 19    18.379046
# 20    15.533129
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.973
# Method:                 Least Squares   F-statistic:                              772.0
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    1.88e-17
# Time:                        16:39:54   Log-Likelihood:                         -51.284
# ...

# %%
b_sqrt = np.sqrt(df['Delivery Time'])
model5 = sm.OLS(b_sqrt,a).fit()
pred5 = model5.predict(a_sqrt)
print(pred5)
model5.summary()
# Out:
# 0     1.873833
# 1     1.185116
# 2     1.451465
# 3     1.777674
# 4     1.873833
# 5     1.451465
# 6     1.567761
# 7     1.026341
# 8     1.873833
# 9     1.777674
# 10    1.676007
# 11    1.185116
# 12    1.567761
# 13    1.026341
# 14    1.026341
# 15    1.185116
# 16    1.451465
# 17    1.567761
# 18    0.838004
# 19    1.567761
# 20    1.325000
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.930
# Model:                            OLS   Adj. R-squared (uncentered):              0.927
# Method:                 Least Squares   F-statistic:                              266.0
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    5.09e-13
# Time:                        16:39:54   Log-Likelihood:                         -31.484
# ...

# %%
model6 = sm.OLS(b_sqrt, a_sqrt).fit()
pred6 = model6.predict(a_sqrt)
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              1542.
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    2.10e-20
# Time:                        16:39:54   Log-Likelihood:                         -13.658
# No. Observations:                  21   AIC:                                      29.32
# Df Residuals:                      20   BIC:                                      30.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# QUESTION 2

# %%
data = pd.read_csv(r"C:\Users\cindr\Downloads\Salary_Data.csv")

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = data['YearsExperience']
y = data['Salary']

# %%
x,y
# Out:
# (0      1.1
#  1      1.3
#  2      1.5
#  3      2.0
#  4      2.2
#  5      2.9
#  6      3.0
#  7      3.2
#  8      3.2
#  9      3.7
#  10     3.9
#  11     4.0
#  12     4.0
#  13     4.1
#  14     4.5
#  15     4.9
#  16     5.1
#  17     5.3
#  18     5.9
#  19     6.0
#  20     6.8
#  21     7.1
#  22     7.9
#  23     8.2
#  24     8.7
#  25     9.0
#  26     9.5
#  27     9.6
#  28    10.3
#  29    10.5
#  Name: YearsExperience, dtype: float64,
#  0      39343.0
#  1      46205.0
#  2      37731.0
#  3      43525.0
#  4      39891.0
#  5      56642.0
#  6      60150.0
#  7      54445.0
#  8      64445.0
#  9      57189.0
#  10     63218.0
#  11     55794.0
#  12     56957.0
#  13     57081.0
#  14     61111.0
#  15     67938.0
#  16     66029.0
#  17     83088.0
#  18     81363.0
#  19     93940.0
#  20     91738.0
#  21     98273.0
#  22    101302.0
#  23    113812.0
#  24    109431.0
#  25    105582.0
#  26    116969.0
#  27    112635.0
#  28    122391.0
# ...

# %%
sns.pairplot(data, kind='reg')
plt.show()

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
corr = np.corrcoef(x, y)
print(corr)
# Out:
# [[1.         0.97824162]
#  [0.97824162 1.        ]]

# %%
# model without transformation 
model7 =sm.OLS(x,y).fit()
pred7= model7.predict()
print(pred7)
model7.summary()
# Out:
# [2.88827099 3.39202809 2.76992992 3.19528238 2.92850108 4.15823515
#  4.41576646 3.99694772 4.73107348 4.19839183 4.64099625 4.09598128
#  4.18136011 4.19046327 4.48631595 4.98750361 4.847359   6.09970414
#  5.97306745 6.89637742 6.73472292 7.21447411 7.4368408  8.35523213
#  8.03361164 7.75104663 8.58699564 8.26882553 8.98503863 8.9469375 ]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:        YearsExperience   R-squared (uncentered):                   0.973
# Model:                            OLS   Adj. R-squared (uncentered):              0.972
# Method:                 Least Squares   F-statistic:                              1048.
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    2.56e-24
# Time:                        16:39:57   Log-Likelihood:                         -42.105
# No. Observations:                  30   AIC:                                      86.21
# ...

# %%
# reciprocal transformation for x, y and check my model performance
x_rec = np.reciprocal(x)
x_rec
# Out:
# 0     0.909091
# 1     0.769231
# 2     0.666667
# 3     0.500000
# 4     0.454545
# 5     0.344828
# 6     0.333333
# 7     0.312500
# 8     0.312500
# 9     0.270270
# 10    0.256410
# 11    0.250000
# 12    0.250000
# 13    0.243902
# 14    0.222222
# 15    0.204082
# 16    0.196078
# 17    0.188679
# 18    0.169492
# 19    0.166667
# 20    0.147059
# 21    0.140845
# 22    0.126582
# 23    0.121951
# 24    0.114943
# 25    0.111111
# 26    0.105263
# 27    0.104167
# 28    0.097087
# 29    0.095238
# Name: YearsExperience, dtype: float64

# %%
# model using x_rec transformation 
model8 = sm.OLS(x_rec,y).fit()
pred8 =model8.predict(x_rec)
pred8
model8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:        YearsExperience   R-squared (uncentered):                   0.371
# Model:                            OLS   Adj. R-squared (uncentered):              0.350
# Method:                 Least Squares   F-statistic:                              17.12
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    0.000275
# Time:                        16:39:57   Log-Likelihood:                         -3.0683
# No. Observations:                  30   AIC:                                      8.137
# Df Residuals:                      29   BIC:                                      9.538
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_log = np.log(data['YearsExperience'])
model9 = sm.OLS(y, x_log).fit()
pred9 = model.predict(x_log)
model9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              1338.
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    8.06e-26
# Time:                        16:39:57   Log-Likelihood:                         -323.70
# No. Observations:                  30   AIC:                                      649.4
# Df Residuals:                      29   BIC:                                      650.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
y_log = np.log(data['Salary'])
model10 = sm.OLS(y_log, x).fit()
pred10 = model.predict(x)
model10.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.809
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                              122.8
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    6.09e-12
# Time:                        16:39:57   Log-Likelihood:                         -90.160
# No. Observations:                  30   AIC:                                      182.3
# Df Residuals:                      29   BIC:                                      183.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model11 = sm.OLS(y_log, x_log).fit()
pred11 = model.predict(x_log)
model11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.878
# Model:                            OLS   Adj. R-squared (uncentered):              0.874
# Method:                 Least Squares   F-statistic:                              209.1
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    8.60e-15
# Time:                        16:39:57   Log-Likelihood:                         -83.410
# No. Observations:                  30   AIC:                                      168.8
# Df Residuals:                      29   BIC:                                      170.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x_sqrt = np.sqrt(data['YearsExperience'])
model12 = sm.OLS(y, x_sqrt).fit()
pred12 = model.predict(x_sqrt)
model12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.989
# Model:                            OLS   Adj. R-squared (uncentered):              0.989
# Method:                 Least Squares   F-statistic:                              2697.
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    3.62e-30
# Time:                        16:39:58   Log-Likelihood:                         -313.35
# No. Observations:                  30   AIC:                                      628.7
# Df Residuals:                      29   BIC:                                      630.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
y_sqrt = np.sqrt(data['Salary'])
model13 = sm.OLS(y_sqrt, x).fit()
pred13 = model.predict(x)
model13.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.906
# Model:                            OLS   Adj. R-squared (uncentered):              0.902
# Method:                 Least Squares   F-statistic:                              278.1
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    2.12e-16
# Time:                        16:39:58   Log-Likelihood:                         -175.75
# No. Observations:                  30   AIC:                                      353.5
# Df Residuals:                      29   BIC:                                      354.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model14 = sm.OLS(y_sqrt, x_sqrt).fit()
pred14 = model.predict(x_sqrt)
model14.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              2338.
# Date:                Sat, 29 Oct 2022   Prob (F-statistic):                    2.81e-29
# Time:                        16:39:58   Log-Likelihood:                         -145.12
# No. Observations:                  30   AIC:                                      292.2
# Df Residuals:                      29   BIC:                                      293.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
## model 12 has the best R square value

# %%
2**32
# Out:
# 4294967296
